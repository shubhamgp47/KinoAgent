# %%
from pathlib import Path
import os

PROJECT_ROOT = Path(__file__).resolve().parent

DATA_DIR = Path(os.getenv("KINOAGENT_DATA_DIR", PROJECT_ROOT / "data"))
OSCARS_DB_PATH = str(DATA_DIR / "oscars_db" / "oscars.db")

oscars_path = Path(OSCARS_DB_PATH).resolve()
print("Absolute Path:", oscars_path)
print("File exists?:", oscars_path.is_file())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from pathlib import Path
#       2 import os
#       3
# ----> 4 DATA_DIR = Path(os.getenv("KINOAGENT_DATA_DIR", PROJECT_ROOT / "data"))
#       5 OSCARS_DB_PATH = str(DATA_DIR / "oscars_db" / "oscars.db")
#       6
#       7 oscars_path = Path(OSCARS_DB_PATH).resolve()
#
# NameError: name 'PROJECT_ROOT' is not defined
