# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("unanimad/the-oscar-award")

print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\shubh\.cache\kagglehub\datasets\unanimad\the-oscar-award\13.archive...
# 100%|██████████| 743k/743k [00:00<00:00, 1.27MB/s]
# Extracting files...
# Path to dataset files: C:\Users\shubh\.cache\kagglehub\datasets\unanimad\the-oscar-award\versions\13
